# %%
#w/ radar setup, interference from rotary encoder present
from gpiozero import DistanceSensor
from time import sleep
from matplotlib import pyplot as plt

sensor = DistanceSensor(echo=23, trigger=24)
x = []
y = []

if __name__ == "__main__":
    try:
        time = 0
        while True:
            dis = sensor.distance*100
            print("Distance: {:.2f} cm".format(dis))
            x.append(time)
            y.append(dis)
            time+=1
            sleep(1)
    except KeyboardInterrupt:
        plt.plot(x,y)
        plt.xlabel("time (s)")
        plt.ylabel("distance (cm)")
        plt.title("distance as a function of time")
        plt.show()
        sensor.close()
# Out:
# /home/markfu/jupyterlab_env/lib/python3.11/site-packages/gpiozero/input_devices.py:852: PWMSoftwareFallback: For more accurate readings, use the pigpio pin factory.See https://gpiozero.readthedocs.io/en/stable/api_input.html#distancesensor-hc-sr04 for more info
#   warnings.warn(PWMSoftwareFallback(
# /home/markfu/jupyterlab_env/lib/python3.11/site-packages/gpiozero/input_devices.py:945: DistanceSensorNoEcho: echo pin set high
#   warnings.warn(DistanceSensorNoEcho('echo pin set high'))
# Distance: 0.41 cm
# Distance: 0.91 cm
# Distance: 1.29 cm
# Distance: 1.29 cm
# Distance: 1.30 cm
# Distance: 1.29 cm
# Distance: 1.28 cm
# Distance: 1.29 cm
# Distance: 1.28 cm
# Distance: 1.28 cm
# Distance: 1.28 cm
# Distance: 1.27 cm
# Distance: 1.29 cm
# Distance: 1.27 cm
# Distance: 1.31 cm
# Distance: 1.29 cm
# Distance: 1.28 cm
# Distance: 0.53 cm
# Distance: 0.56 cm
# Distance: 0.51 cm
# Distance: 0.35 cm
# Distance: 0.36 cm
# Distance: 0.53 cm
# Distance: 0.65 cm
# Distance: 0.38 cm
# Distance: 0.40 cm
# Distance: 0.55 cm
# Distance: 0.42 cm
# Distance: 0.48 cm
# Distance: 0.46 cm
# Distance: 0.49 cm
# Distance: 0.48 cm
# Distance: 0.64 cm
# Distance: 0.38 cm
# Distance: 1.13 cm
# Distance: 0.45 cm
# Distance: 0.50 cm
# Distance: 1.20 cm
# Distance: 1.20 cm
# Distance: 1.02 cm
# Distance: 1.13 cm
